# %%
import pandas as pd
data = pd.read_csv("FOE.csv")
data.sample(15)
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 7480   2009-11-05   5.830000   6.500000   5.820000   6.440000   6.440000
# 8265   2012-12-19   3.280000   3.570000   3.270000   3.430000   3.430000
# 10577  2022-02-25  21.700001  21.770000  21.639999  21.740000  21.740000
# 8202   2012-09-18   4.140000   4.200000   4.090000   4.130000   4.130000
# 5586   2002-05-01  28.320000  28.379999  27.690001  28.360001  23.381639
# 6564   2006-03-20  20.000000  20.100000  19.799999  20.049999  18.305544
# 9454   2017-09-11  19.620001  20.070000  19.540001  20.049999  20.049999
# 4254   1997-01-13  19.166668  19.166668  18.916668  19.083332  13.871902
# 717    1983-01-17   0.000000   4.222222   4.129630   4.166667   2.250739
# 9778   2018-12-24  15.300000  15.400000  14.950000  15.090000  15.090000
# 7301   2009-02-23   1.970000   2.030000   1.520000   1.520000   1.520000
# 2884   1991-08-13  12.111111  12.222222  11.944444  12.222222   8.044361
# ...

# %% [markdown]
# data cleaning and exploration

# %%
# check for null values
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# data description
data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10590.000000  10590.000000  10590.000000  10590.000000  10590.000000
# mean      13.607281     14.631222     14.240872     14.439353     11.952665
# std        8.521814      7.381201      7.230212      7.309994      6.597625
# min        0.000000      1.010000      0.810000      0.860000      0.860000
# 25%        7.072500      7.740000      7.420000      7.611111      5.995661
# 50%       14.860000     15.080000     14.666667     14.865000     12.818146
# 75%       20.610001     20.847500     20.333332     20.620001     17.534573
# max       30.250000     30.937500     30.000000     30.549999     25.350000
#
#              Volume
# count  1.059000e+04
# mean   3.662785e+05
# std    6.056098e+05
# min    0.000000e+00
# 25%    7.695000e+04
# 50%    1.966500e+05
# 75%    4.675750e+05
# max    2.044590e+07

# %%
data.plot(x= None, y= None)
# Out:
# <AxesSubplot:>

# %%
data["Open"].plot(x= None, y= None, color="blue")
# Out:
# <AxesSubplot:>

# %%
data["Close"].plot(x= None, y= None, color= "red")
# Out:
# <AxesSubplot:>

# %%
data["High"].plot(x= None, y= None, color= "orange")
# Out:
# <AxesSubplot:>

# %%
data["Low"].plot(x= None, y= None, color= "green")
# Out:
# <AxesSubplot:>

# %%
data["Adj Close"].plot(x= None, y= None, color= "purple")
# Out:
# <AxesSubplot:>

# %%
data["Volume"].plot(x= None, y= None, color= "brown")
# Out:
# <AxesSubplot:>

# %% [markdown]
# main interest is the time series for volume over the years
#
# thus, drop the other columns

# %%
data = data.drop(["Open", "Close", "High", "Low", "Adj Close"], axis= "columns")
data.head()
# Out:
#          Date  Volume
# 0  1980-03-17   47925
# 1  1980-03-18   77625
# 2  1980-03-19   35775
# 3  1980-03-20   42525
# 4  1980-03-21   37125

# %%
data.plot(x=None, y= None)
# Out:
# <AxesSubplot:>
