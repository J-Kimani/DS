# %%
import numpy as np
from scipy import stats

# Data
lifetimes = np.array([11018.0428, 10121.5616, 10658.5262, 11688.5888, 11465.9083,
                      10325.3182, 11729.7817, 11868.2553, 12027.2639, 10699.2647,
                      10388.4929, 11101.4623, 10981.0561, 11750.6379, 10759.0967,
                      11828.0887, 10099.3098, 13082.9461, 11626.6513, 10093.5286,
                      10528.9536, 11204.0733, 11076.8096, 12658.5981, 10367.6746,
                      12242.3667, 10717.9830, 10810.7953, 10219.2189, 9851.2983,
                      11716.2374, 8186.5991, 9825.3434, 9663.8268, 8247.0955,
                      9146.5127, 10425.0859, 9614.7231, 10673.5858, 11619.6077,
                      12171.4116, 10863.2035, 13367.7022, 9959.5881, 11183.4597])

n = len(lifetimes)
mu_0 = 11000  # claimed mean
alpha = 0.05

# Sample mean and standard deviation
x_bar = np.mean(lifetimes)
s = np.std(lifetimes, ddof=1)

# t-statistic for left-tailed test
t_stat = (x_bar - mu_0) / (s / np.sqrt(n))

# p-value for left-tailed test
p_value = stats.t.cdf(t_stat, df=n-1)

x_bar, t_stat, p_value
# Out:
# (10881.234128888887, -0.7303597679088429, 0.23452071820820797)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Pole heights data

heights = np.array([36.800, 33.989, 41.826, 51.493, 25.676, 37.660, 44.955, 33.930,
35.157, 24.582, 57.839, 37.415, 41.108, 36.451, 43.073, 32.207,
15.925, 33.725, 19.037, 31.858, 54.274, 45.742, 23.825, 40.365,
56.749, 44.748, 33.035, 32.672, 33.746, 30.770, 51.299, 34.056,
53.600, 30.822, 42.339, 48.492, 30.187, 32.529, 42.662, 35.094,
27.514, 30.653, 41.301, 41.223, 24.908, 23.804, 48.525, 37.840,
48.597, 42.087, 28.534, 38.033, 31.700, 44.479, 31.450, 35.304,
32.475, 25.172, 50.710, 36.111])

# Sample size

n = len(heights)

# Claimed mean

mu_0 = 40

# Sample mean

x_bar = np.mean(heights)

# Sample standard deviation

s = np.std(heights, ddof=1)  # ddof=1 for sample std

# t-statistic

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))

# Degrees of freedom

df = n - 1

# p-value for two-tailed test

p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df))

# Output results

print(f"Sample mean (x̄): {x_bar:.3f}")
print(f"Sample std (s): {s:.3f}")
print(f"t-statistic: {t_stat:.3f}")
print(f"p-value: {p_value:.3f}")

# Histogram

plt.hist(heights, bins=10, edgecolor='black')
plt.axvline(x_bar, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean = {x_bar:.2f}')
plt.title('Histogram of Pole Heights')
plt.xlabel('Height (feet)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Sample mean (x̄): 37.202
# Sample std (s): 9.314
# t-statistic: -2.327
# p-value: 0.023
