# %% [markdown]
# # 🎵 Music Popularity Prediction (R Version)
#
# ## Objective
# Predict the popularity score of songs using regression models based on their audio features. This supports better playlist curation, user recommendations, and strategic music marketing.
#
# ## Dataset
# - Source: Kaggle (Spotify Most Popular Songs)
# - Features: Danceability, energy, tempo, etc.
# - Target: `popularity` (score from 0 to 100)
#
# ## Workflow
# 1. Load and clean data
# 2. Perform exploratory data analysis (EDA)
# 3. Engineer relevant features
# 4. Train regression models (e.g., Linear, Random Forest, XGBoost)
# 5. Evaluate using RMSE, MAE, R²
# 6. Interpret model results

# %%
df <- read.csv("songs.csv")
head(df)
# Out:
#   X track_id               track_name
# 1 0 6oJ6le65B3SEqPwMRNXWjY higher love
# 2 1 3yNZ5r3LKfdmjoS3gkhUCT bad guy (with justin bieber)
# 3 2 0qc4QlcCxVTGyShurEv1UU post malone (feat. rani)
# 4 3 4PkIDTPGedm0enzdvilLNd sixteen
# 5 4 5PYQUBXc7NYeI1obMKSJK0 never really over
# 6 5 4Gcv5SsxnQWpmOnUI19EJk all you need to know (feat. calle lehmann)
#   track_artist  track_popularity track_album_release_date playlist_genre
# 1 Kygo          0.5000000        2019-06-28               Pop
# 2 Billieeilish  0.3181818        2019-07-11               Pop
# 3 Samfeldt      0.3181818        2019-05-24               Pop
# 4 Elliegoulding 0.2272727        2019-04-12               Pop
# 5 Katyperry     0.4090909        2019-05-31               Pop
# 6 Gryffin       0.0000000        2019-03-27               Pop
#   danceability energy    key       ⋯ track_artist_merged
# 1 0.6326797    0.6673463 0.7272727 ⋯ kygo
# 2 0.6026144    0.4259041 0.0000000 ⋯ billie eilish
# ...

# %%
colnames(df)
# Out:
#  [1] "X"                        "track_id"
#  [3] "track_name"               "track_artist"
#  [5] "track_popularity"         "track_album_release_date"
#  [7] "playlist_genre"           "danceability"
#  [9] "energy"                   "key"
# [11] "loudness"                 "mode"
# [13] "speechiness"              "acousticness"
# [15] "liveness"                 "valence"
# [17] "tempo"                    "duration_ms"
# [19] "track_artist_merged"      "lyrics"
# [21] "artist_name"              "tags"
# [23] "tags_tokenized"           "doc_vector"
# [25] "combined_vector"          "cluster"
# [27] "image_url"                "spotify_url"

# %%
library(dplyr)
# Select only relevant columns (rename or exclude missing ones)
clean_df <- df %>%
  select(
    track_name,
    track_artist,
    track_id,
    track_popularity,
    track_album_release_date,
    duration_ms,
    spotify_url,
    danceability,
    energy,
    key,
    loudness,
    mode,
    speechiness,
    acousticness,
    liveness,
    valence,
    tempo
  )
# Out:
# Error in library(dplyr): there is no package called 'dplyr'
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))
